# %% [markdown]
# <a href="https://colab.research.google.com/github/Sehastrajit/Projects/blob/main/HMS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My Drive/Colab Notebooks
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
ls
# Out:
# 1000086677.parquet  1001369401.parquet  HMS.ipynb          Tamil_CNN.ipynb
# 1000913311.parquet  1001487592.parquet  medical_cnn.ipynb

# %% [markdown]
# # TEST

# %%
pip install fastparquet
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 14.8 MB/s eta 0:00:00
# ...

# %%
from fastparquet import ParquetFile

# Reading the data from Parquet File
pf = ParquetFile("1000913311.parquet")

# Converting data in to pandas dataFrame
dataFrame = pf.to_pandas()

# Converting to CSV
dataFrame.to_csv("converted.csv", index = False)

# %%
dataFrame
# Out:
#              Fp1          F3          C3          P3          F7          T3  \
# 0    -105.849998  -89.230003  -79.459999  -49.230000  -99.730003  -87.769997
# 1     -85.470001  -75.070000  -60.259998  -38.919998  -73.080002  -87.510002
# 2       8.840000   34.849998   56.430000   67.970001   48.099998   25.350000
# 3     -56.320000  -37.279999  -28.100000   -2.820000  -43.430000  -35.049999
# 4    -110.139999 -104.519997  -96.879997  -70.250000 -111.660004 -114.430000
# ...          ...         ...         ...         ...         ...         ...
# 9995  -45.540001  -26.459999  -23.209999  -25.250000  -21.559999  -36.549999
# 9996  -26.860001    4.350000    7.410000    7.830000    5.260000    7.750000
# 9997 -133.759995 -111.190002 -119.180000 -105.760002 -130.039993 -104.059998
# 9998  -78.889999  -59.660000  -60.770000  -59.810001  -63.020000  -60.020000
# 9999    3.780000   36.009998   41.060001   34.389999   42.340000   37.709999
#
# ...

# %% [markdown]
# EEG

# %%
import pandas as pd
df=pd.read_parquet("1000913311.parquet")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-9745ad5f0454> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df=pd.read_parquet("1000913311.parquet")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     501     impl = get_engine(engine)
#     502
# --> 503     return impl.read(
#     504         path,
#     505         columns=columns,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     242             to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
#     243
# --> 244         path_or_handle, handles, kwargs["filesystem"] = _get_path_or_handle(
#     245             path,
#     246             kwargs.pop("filesystem", None),
#
# ...

# %%
df
# Out:
#              Fp1          F3          C3          P3          F7          T3  \
# 0    -105.849998  -89.230003  -79.459999  -49.230000  -99.730003  -87.769997
# 1     -85.470001  -75.070000  -60.259998  -38.919998  -73.080002  -87.510002
# 2       8.840000   34.849998   56.430000   67.970001   48.099998   25.350000
# 3     -56.320000  -37.279999  -28.100000   -2.820000  -43.430000  -35.049999
# 4    -110.139999 -104.519997  -96.879997  -70.250000 -111.660004 -114.430000
# ...          ...         ...         ...         ...         ...         ...
# 9995  -45.540001  -26.459999  -23.209999  -25.250000  -21.559999  -36.549999
# 9996  -26.860001    4.350000    7.410000    7.830000    5.260000    7.750000
# 9997 -133.759995 -111.190002 -119.180000 -105.760002 -130.039993 -104.059998
# 9998  -78.889999  -59.660000  -60.770000  -59.810001  -63.020000  -60.020000
# 9999    3.780000   36.009998   41.060001   34.389999   42.340000   37.709999
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the provided text
data = pd.read_parquet("1001369401.parquet")

# Convert the dictionary to a DataFrame
df = pd.DataFrame(data)

# Plot EEG data for each electrode channel
plt.figure(figsize=(12, 6))
for column in df.columns:
    plt.plot(df.index, df[column], label=column)

plt.xlabel('Time')
plt.ylabel('EEG Amplitude')
plt.title('EEG Data')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_parquet("1000086677.parquet")
df = pd.DataFrame(data)

# %%
plt.figure(figsize=(12, 6))
for column in df.columns:
    plt.plot(df.index, df[column], label=column)

plt.xlabel('Time')
plt.ylabel('EEG Amplitude')
plt.title('EEG Data')
plt.legend()
plt.show()
